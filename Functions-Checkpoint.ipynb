# %%
def calculator(num1, num2):
    operator = input("Enter the operator (+, -, *, /): ")

    if operator == "+":
        return num1 + num2
    elif operator == "-":
        return num1 - num2
    elif operator == "*":
        return num1 * num2
    elif operator == "/":
        if num2 == 0:
            return "Division by zero is not allowed."
        return num1 / num2
    else:
        return "Invalid operator."

print("Welcom to Calculator \n")   

while True:
    
    number1 = float(input("Enter the first number: "))
    number2 = float(input("Enter the second number: "))

    result = calculator(number1, number2)
    print("The result is:", result, "\n")

    user_choice = input("Press Enter to continue or type 'end' to quit: ")

    if user_choice == "end":
        print("Thanks for using the calculator. Goodbye!")
        break
# Out:
# Welcom to Calculator
#
# The result is: -3.0
#
# Thanks for using the calculator. Goodbye!
